# %%
import pandas as pd

# %%
pops = pd.read_csv('populations.csv')

# %%
pops.describe()
# Out:
#           SUMLEV      STATE  CENSUS2010POP  ESTIMATESBASE2010  \
# count  57.000000  57.000000   5.700000e+01       5.700000e+01
# mean   38.070175  27.175439   1.631513e+07       1.631580e+07
# std     6.391567  18.125675   4.436075e+07       4.436260e+07
# min    10.000000   0.000000   5.636260e+05       5.637750e+05
# 25%    40.000000  12.000000   1.852994e+06       1.853018e+06
# 50%    40.000000  27.000000   4.625364e+06       4.625366e+06
# 75%    40.000000  41.000000   9.535483e+06       9.535751e+06
# max    40.000000  72.000000   3.087455e+08       3.087581e+08
#
#        POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# count     5.700000e+01     5.700000e+01     5.700000e+01     5.700000e+01
# mean      1.634538e+07     1.646227e+07     1.658118e+07     1.669428e+07
# std       4.444586e+07     4.477654e+07     4.511484e+07     4.543594e+07
# min       5.644870e+05     5.672990e+05     5.763050e+05     5.821220e+05
# ...

# %%
us_pop = pops[pops['NAME'] == 'United States'].values[0][5]
us_pop
# Out:
# 308745538

# %%
drop = ['Northeast Region', 'Midwest Region', 'West Region', 'South Region', 'Puerto Rico', 'United States']
pops = pops[~pops['NAME'].isin(drop)]

# %%
pops = pops.sort_values('CENSUS2010POP')
pops
# Out:
#     SUMLEV REGION DIVISION  STATE                  NAME  CENSUS2010POP  \
# 55      40      4        8     56               Wyoming         563626
# 13      40      3        5     11  District of Columbia         601723
# 50      40      1        1     50               Vermont         625741
# 39      40      2        4     38          North Dakota         672591
# 6       40      4        9      2                Alaska         710231
# 46      40      2        4     46          South Dakota         814180
# 12      40      3        5     10              Delaware         897934
# 31      40      4        8     30               Montana         989415
# 44      40      1        1     44          Rhode Island        1052567
# 34      40      1        1     33         New Hampshire        1316470
# 24      40      1        1     23                 Maine        1328361
# 16      40      4        9     15                Hawaii        1360301
# ...

# %%
def population(state, pops=pops):
    if (state == 'DC'):
        state = 'District of Columbia'
    return pops[pops['NAME'] == state].values[0][5]

# %%
list(pops.sum())[5], us_pop
# Out:
# (308745538, 308745538)

# %%
votes_remaining_rounded = 538
votes_remaining_prop = 538
for index, row in pops.iterrows():
    votes = population(row['NAME']) / us_pop * 538
    if votes < 1:
        votes = 1
    votes_prop = min(votes_remaining_prop, votes)
    votes_round = round(min(votes_remaining_rounded, votes))
    
    votes_remaining_rounded -= votes_round
    votes_remaining_prop -= votes_prop
    pops.loc[index, 'prop_votes'] = votes_prop
    pops.loc[index, 'rounded_votes'] = votes_round

pops
# Out:
#     SUMLEV REGION DIVISION  STATE                  NAME  CENSUS2010POP  \
# 55      40      4        8     56               Wyoming         563626
# 13      40      3        5     11  District of Columbia         601723
# 50      40      1        1     50               Vermont         625741
# 39      40      2        4     38          North Dakota         672591
# 6       40      4        9      2                Alaska         710231
# 46      40      2        4     46          South Dakota         814180
# 12      40      3        5     10              Delaware         897934
# 31      40      4        8     30               Montana         989415
# 44      40      1        1     44          Rhode Island        1052567
# 34      40      1        1     33         New Hampshire        1316470
# 24      40      1        1     23                 Maine        1328361
# 16      40      4        9     15                Hawaii        1360301
# ...

# %%
pops['rounded_votes'].sum()
# Out:
# 537.0

# %%
# give missouri an extra vote because they're lose the most votes (.43 lost)
pops.at[30, 'rounded_votes'] = 11
pops
# Out:
#     SUMLEV REGION DIVISION  STATE                  NAME  CENSUS2010POP  \
# 55      40      4        8     56               Wyoming         563626
# 13      40      3        5     11  District of Columbia         601723
# 50      40      1        1     50               Vermont         625741
# 39      40      2        4     38          North Dakota         672591
# 6       40      4        9      2                Alaska         710231
# 46      40      2        4     46          South Dakota         814180
# 12      40      3        5     10              Delaware         897934
# 31      40      4        8     30               Montana         989415
# 44      40      1        1     44          Rhode Island        1052567
# 34      40      1        1     33         New Hampshire        1316470
# 24      40      1        1     23                 Maine        1328361
# 16      40      4        9     15                Hawaii        1360301
# ...

# %%
pops['rounded_votes'].sum()
# Out:
# 538.0

# %%
trump = 0
biden = 0
blue = ['California', 'New York', 'Illinois', 'Pennsylvania', 'Michigan', 'Georgia', 'Virginia', 'Washington', 'Massachusetts', 'Arizona', 'Maryland', 'Wisconsin', 'Minnesota', 'Colorado', 'Oregon', 'Connecticut', 'Nevada', 'New Mexico', 'Hawaii', 'New Hampshire', 'Rhode Island', 'Delaware', 'Vermont', 'District of Columbia']

r_states = []
b_states = []

no_winner = True
for index, row in reversed(list(pops.iterrows())):
    name = row['NAME']
    if name == 'Maine':
        trump += 1
        biden += 1
        r_states.append(name)
        b_states.append(name)
    elif name == 'Nebraska':
        trump += 2
        biden += 1
        r_states.append(name)
    else:
        if name in blue:
            biden += row['rounded_votes']
            b_states.append(name)
        else:
            trump += row['rounded_votes']
            r_states.append(name)
    if no_winner:
        if trump > 270:
            print("Trump won with ", ', '.join(r_states))
            no_winner = False
        elif biden > 270:
            print('Biden won with ', ', '.join(b_states))
            no_winner = False
            

print('Trump: ', trump)
print('Biden: ', biden)
# Out:
# Biden won with  California, New York, Illinois, Pennsylvania, Michigan, Georgia, Virginia, Washington, Massachusetts, Arizona, Maryland, Wisconsin, Minnesota, Colorado, Oregon, Connecticut
# Trump:  241.0
# Biden:  297.0

# %%
for index, row in pops.iterrows():
    print(row['NAME'], ': ', row['rounded_votes'])
# Out:
# Wyoming :  1.0
# District of Columbia :  1.0
# Vermont :  1.0
# North Dakota :  1.0
# Alaska :  1.0
# South Dakota :  1.0
# Delaware :  2.0
# Montana :  2.0
# Rhode Island :  2.0
# New Hampshire :  2.0
# Maine :  2.0
# Hawaii :  2.0
# Idaho :  3.0
# Nebraska :  3.0
# West Virginia :  3.0
# New Mexico :  4.0
# Nevada :  5.0
# Utah :  5.0
# Kansas :  5.0
# Arkansas :  5.0
# Mississippi :  5.0
# Iowa :  5.0
# Connecticut :  6.0
# Oklahoma :  7.0
# Oregon :  7.0
# Kentucky :  8.0
# Louisiana :  8.0
# South Carolina :  8.0
# Alabama :  8.0
# Colorado :  9.0
# Minnesota :  9.0
# Wisconsin :  10.0
# Maryland :  10.0
# Missouri :  11.0
# Tennessee :  11.0
# Arizona :  11.0
# Indiana :  11.0
# Massachusetts :  11.0
# Washington :  12.0
# Virginia :  14.0
# New Jersey :  15.0
# North Carolina :  17.0
# Georgia :  17.0
# Michigan :  17.0
# Ohio :  20.0
# Pennsylvania :  22.0
# Illinois :  22.0
# Florida :  33.0
# New York :  34.0
# Texas :  44.0
# California :  65.0
